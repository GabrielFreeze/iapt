# %% [markdown]
# ### Picking which words are valid for the crossword
# The words will be saved in a csv file. alongside any relevant information.

# %%
import os
import re
import numpy as np
import pandas as pd
import time
import json

frequency_path = os.path.join(os.getcwd(),'..','data','korpus','korpus_frequency.csv')
wordforms_path = os.path.join(os.getcwd(),'..','data','gabra','wordforms.csv')
lessiku_path = os.path.join(os.getcwd(),'..','data','gabra','lexemes.csv')
final_lexemes_path = os.path.join(os.getcwd(),'..','data','gabra','final','lexemes.csv')

# %%
#Load frequency counts of words from korpus
df_frequency = pd.read_csv(frequency_path)

#Load lexemes
df_lexemes = pd.read_csv(lessiku_path, encoding='utf-32')[["_id","lemma","root","sources","phonetic","pos","glosses"]]

# %%
df_lexemes = df_lexemes[df_lexemes['sources'] != "['UserFeedback']"]
df_lexemes = df_lexemes.dropna()

# %%
df_lexemes
# Out:
#                             _id     lemma  \
# 0      5200a366e36f237975000783    badbad
# 1      5200a366e36f237975000784   tbadbad
# 2      5200a366e36f237975000785   bagħbas
# 3      5200a366e36f237975000786  tbagħbas
# 4      5200a366e36f237975000787   bagħtar
# ...                         ...       ...
# 16833  569002ffdff0600b5ab1434e  mgħarwel
# 16837  56966190189d1d6376783b94    ħaxixa
# 16846  569794e16e68020d08030c4d     kitba
# 16982  5714de59418362c403b9c3ff    xagħat
# 18950  5c584ad8bd4e49047363e116    tidris
#
#                                       root                        sources  \
# 0                  {'radicals': 'b-d-b-d'}  ['Spagnol2011', 'Falzon2013']
# 1                  {'radicals': 'b-d-b-d'}                ['Spagnol2011']
# 2                 {'radicals': 'b-għ-b-s'}  ['Spagnol2011', 'Falzon2013']
# 3                 {'radicals': 'b-għ-b-s'}                ['Spagnol2011']
# 4                 {'radicals': 'b-għ-t-r'}                ['Spagnol2011']
# ...                                    ...                            ...
# 16833             {'radicals': 'għ-r-w-l'}     ['UserFeedback', 'DM2015']
# 16837                {'radicals': 'ħ-x-x'}                     ['DM2015']
# 16846                {'radicals': 'k-t-b'}                     ['DM2015']
# 16982               {'radicals': 'x-għ-t'}                     ['DM2015']
# 18950  {'radicals': 'd-r-s', 'variant': 1}                     ['DM2015']
#
#       phonetic   pos                                            glosses
# 0       bɐdbɐt  VERB  [{'gloss': 'to fornicate', 'examples': []}, {'...
# 1      dbɐdbɐt  VERB  [{'gloss': 'to act in a rough or anti-social m...
# 2       bɐːbɐs  VERB  [{'gloss': 'to touch', 'examples': []}, {'glos...
# 3      dbɐːbɐs  VERB  [{'gloss': 'to be damaged as a result of handl...
# 4       bɐːtɐr  VERB  [{'gloss': 'to wade through mud', 'examples': ...
# ...        ...   ...                                                ...
# 16833  mɐːrwɛl   ADJ            [{'gloss': 'swarming', 'examples': []}]
# 16837   hɐʃɪʃɐ  NOUN  [{'gloss': 'colloquial term for marijuana', 'e...
# 16846    kɪdbɐ  NOUN  [{'gloss': 'writing', 'examples': [{'example':...
# 16982     ʃɐːt  NOUN  [{'gloss': 'caterpillar', 'examples': [{'examp...
# 18950   tɪdrɪs  NOUN  [{'gloss': 'irritation or excessive sensitivit...
#
# [10340 rows x 7 columns]

# %%
print(df_lexemes[df_lexemes['_id'] =='5200a368e36f23798800000f'].glosses.values[0])
# print(df_lexemes.iloc[3885])
# Out:
# [{'gloss': 'craft', 'examples': []}, {'gloss': 'skill', 'examples': [{'example': 'L- għalliem tal- woodwork , ċertu Mr Gauci , kien jagħmel ħiltu kollha biex lil dawn it- tfal iqabbadhom is-sengħa ta’ mastrudaxxa .', 'type': 'full'}]}, {'gloss': 'ability', 'examples': []}]

# %% [markdown]
# ##### Parsing glosses and seperating examples

# %%
#Load frequency counts of words from korpus
df_frequency = pd.read_csv(frequency_path)

#Load lexemes
df_lexemes = pd.read_csv(lessiku_path, encoding='utf-32')[["_id","lemma","root","sources","phonetic","pos","glosses"]]

df_lexemes = df_lexemes[df_lexemes['sources'] != "['UserFeedback']"]
df_lexemes = df_lexemes.dropna()

glosses  = []
examples = []

for i,txt in enumerate(df_lexemes['glosses']):
    current_gloss   = []
    current_example = []
    result = re.findall('{(.*)}', txt)
    
    for r in result:
        groups = re.search("'gloss': (.*), 'examples':(.*)",r)
        
        if groups is not None:
            current_gloss.append(groups.group(1))
            print(current_gloss,'\t')
            
            current_examples = groups.group(2)
            current_example = re.search("'example': '(.*)',",current_examples)
               
#             if current_example:
#                 group = current_example.group(1)
#                 index = group.find('}')
                
#                 if index != -1: group = group[:index-16]
                
#                 current_example = group
                
        else:
            current_gloss.append(re.search("'gloss': (.*)",r))
            
        glosses.append(current_gloss)
        examples.append(current_example)
    
# for g in glosses:
#     print(g,'\n\n')
# Out:
# ["'to fornicate', 'examples': []}, {'gloss': 'to cough a lot'"]
# ["'to act in a rough or anti-social manner'"]
# ["'to touch', 'examples': []}, {'gloss': 'to fondle'"]
# ["'to be damaged as a result of handling', 'examples': []}, {'gloss': 'to be messed up'"]
# ["'to wade through mud'"]
# ["'to become muddy'"]
# ["'to make sb. indulge in enjoyment or frivolity'"]
# ["'to have a good time', 'examples': []}, {'gloss': 'to indulge in frivolity'"]
# ["'to wash', 'examples': []}, {'gloss': 'to rinse using a lot of water'"]
# ["'to rinse oneself', 'examples': []}, {'gloss': 'to splash oneself with water'"]
# ["'to blow through a cowrie shell'"]
# ["'to act foolishly'"]
# ["'to become stupid or foolish'"]
# ["'to go soft (somewhat like an overripe fruit)'"]
# ["'to imbibe', 'examples': []}, {'gloss': 'to indulge in excessive drinking'"]
# ["'to be downed quickly (used of drinks)'"]
# ["'to babble', 'examples': []}, {'gloss': 'to talk gibberish'"]
# ["'to flutter'"]
# ["'to sway'"]
# ["'to weaken', 'examples': []}, {'gloss': 'to die down'"]
# ["'to drink (a word used in child-directed speech)'"]
# ["'to hit sb. repeatedly', 'examples': []}, {'gloss': 'to punish', 'examples': []}, {'gloss': 'to pummel'"]
# ["'to ban', 'examples': []}, {'gloss': 'to ostracise', 'examples': []}, {'gloss': 'to exile'"]
# ["'to be announced in public', 'examples': []}, {'gloss': 'to be punished'"]
# ["'to rock from side to side', 'examples': []}, {'gloss': 'to swing'"]
# ["'to be rocked from side to side', 'examples': []}, {'gloss': 'to swing or rock oneself'"]
# ['"to rotate or twirl between one\'s fingers"']
# ["'to be twisted', 'examples': []}, {'gloss': 'to be under the weather'"]
# ["'to bruise', 'examples': []}, {'gloss': 'to make the best of a difficult situation and seek to save face'"]
# ["'to become bruised'"]
# ["'to bubble', 'examples': []}, {'gloss': 'to gurgle', 'examples': []}, {'gloss': 'to boil', 'examples': []}, {'gloss': 'to get sb. worked up and angry'"]
# ["'to get worked up', 'examples': []}, {'gloss': 'to get angry', 'examples': []}, {'gloss': 'to worry'"]
# ["'to romp', 'examples': []}, {'gloss': 'to gad about'"]
# ["'to frequent brothels', 'examples': []}, {'gloss': 'to be turned into a brothel (used of a location)'"]
# ["'to waste', 'examples': []}, {'gloss': 'to squander money'"]
# ["'to be squandered'"]
# ["'to whirr', 'examples': []}, {'gloss': 'to babble'"]
# ["'to steal', 'examples': []}, {'gloss': 'to cheat'"]
# ["'to be stolen'"]
# ["'to fray', 'examples': []}, {'gloss': 'to hem fabric'"]
# ['\'to become frayed\', \'examples\': []}, {\'gloss\': "to lose one\'s good sense"']
# ["'to become infested with fleas'"]
# ["'to mull sth. over', 'examples': []}, {'gloss': 'to make sb. angry'"]
# ["'to become inflamed', 'examples': []}, {'gloss': 'to get angry'"]
# ["'to blossom'"]
# ["'to blossom'"]
# ['"to roll between one\'s fingers (especially used of materials such as paper or dough)"']
# ["'to coo (used of pigeons)'"]
# ["'to sing (used of certain types of birds)'"]
# ["'to do something clumsily', 'examples': []}, {'gloss': 'to stitch in a clumsy fashion'"]
# ["'to be rendered void'"]
# ["'to bake until browned', 'examples': []}, {'gloss': 'to burn (while cooking)'"]
# ["'to be baked until brown', 'examples': []}, {'gloss': 'to be burnt'"]
# ["'to suffice'"]
# ["'to play on a reed-pipe'"]
# ['\'to be very talkative\', \'examples\': []}, {\'gloss\': \'to chatter\', \'examples\': []}, {\'gloss\': "to play the reed pipe (\'betbut\')"']
# ["'to dawn', 'examples': []}, {'gloss': 'to drizzle'"]
# ["'to get wet in a drizzle'"]
# ['"to occupy one\'s mind with sth."']
# ["'to entwine', 'examples': []}, {'gloss': 'to make wicker', 'examples': []}, {'gloss': 'to involve sb. in a compromising situation'"]
# ["'to become involved in a compromising situation'"]
# ["'to exhaust sb.', 'examples': []}, {'gloss': 'to perform a task clumsily', 'examples': []}, {'gloss': 'to cause sth. to become disfigured or misshapen'"]
# ["'to become exhausted', 'examples': []}, {'gloss': 'to become disfigured or misshapen'"]
# ["'to break wind frequently', 'examples': []}, {'gloss': 'to have diarrhoea', 'examples': []}, {'gloss': 'to have to take a child to a doctor very often'"]
# ["'to become ill'"]
# ["'to reprimand', 'examples': []}, {'gloss': 'to seize sb. by the hair (especially their fringe)'"]
# ["'to be reprimanded', 'examples': []}, {'gloss': 'to be castigated', 'examples': []}, {'gloss': 'to experience shock at sth.'"]
# ["'to despise', 'examples': []}, {'gloss': 'sb. who brings another person low'"]
# ['\'to suckle\', \'examples\': []}, {\'gloss\': "to smack one\'s lips or make sucking sounds as one drinks", \'examples\': []}, {\'gloss\': \'to make a mess\'']
# ["'to become overcooked, going soft as a result'"]
# ['"hypothetical Form I of \'tbaxraq\'"']
# ["'to be idle', 'examples': []}, {'gloss': 'to live without working'"]
# ["'to splash'"]
# ["'to turn choppy (used of the sea)'"]
# ['\'to make the eyes blurry\', \'examples\': []}, {\'gloss\': "to make one\'s vision dim"']
# ['"to go dim (used of sb.\'s eyes)", \'examples\': []}, {\'gloss\': "to go blurry (used of sb.\'s eyes)"']
# ["'to shift sth.'"]
# ["'to be shifted'"]
# ["'to splash (e.g. through a puddle)', 'examples': []}, {'gloss': 'to make a mess of sth.', 'examples': []}, {'gloss': 'to wade through water or mud'"]
# ["'to run (used of paint)', 'examples': []}, {'gloss': 'to be splashed (with water, mud etc.)'"]
# ["'to flatten'"]
# ["'to be flattened'"]
# ["'to mist sth. over (e.g. glass)', 'examples': []}, {'gloss': 'to blur', 'examples': []}, {'gloss': 'to obscure or dim'"]
# ["'to become foggy or misty', 'examples': []}, {'gloss': 'to become cloudy (used of the weather)'"]
# ["'to rattle'"]
# ["'to be rattled'"]
# ["'to perform household chores'"]
# ["'to gain weight dramatically'"]
# ["'to sing (only used of certain birds)'"]
# ["'to eat noisily'"]
# ["'to ring', 'examples': []}, {'gloss': 'to call sb. on the phone'"]
# ["'to tinkle', 'examples': []}, {'gloss': 'to chime'"]
# ["'to scold', 'examples': []}, {'gloss': 'to tell off', 'examples': []}, {'gloss': 'to give sb. a dressing down'"]
# ["'to be told off', 'examples': []}, {'gloss': 'to chide oneself'"]
# ["'to diffuse incense', 'examples': []}, {'gloss': 'to be tight-fisted'"]
# ["'to leave sth. unfinished (e.g. a piece of work)', 'examples': []}, {'gloss': 'to leave sb. in the lurch'"]
# ["'to leave sth unfinished (e.g. a piece of work)', 'examples': []}, {'gloss': 'to leave sb. in the lurch'"]
# ["'to wish sb. bad fortune'"]
# ["'to clap', 'examples': []}, {'gloss': 'to applaud'"]
# ["'to make a cracking sound', 'examples': []}, {'gloss': 'to snap'"]
# ["'to be made to crack'"]
# ["'to amble along', 'examples': []}, {'gloss': 'to walk slowly'"]
# ["'to be moved or shifted slowly'"]
# ["'to move', 'examples': []}, {'gloss': 'to shift'"]
# ["'to move', 'examples': []}, {'gloss': 'to be moved', 'examples': []}, {'gloss': 'to be shifted'"]
# ["'to trickle'"]
# ["'to trickle', 'examples': []}, {'gloss': 'to drip'"]
# ["'to be made to trickle', 'examples': []}, {'gloss': 'to be made to run (used of colours and paints)'"]
# ["'to pass the time in idleness', 'examples': []}, {'gloss': 'tp gad about', 'examples': []}, {'gloss': 'to indulge in unseemly behaviour'"]
# ["'to pass the time in idleness', 'examples': []}, {'gloss': 'tp gad about', 'examples': []}, {'gloss': 'to indulge in unseemly behaviour'"]
# ["'to follow sb. slowly (used, e.g., of animals following their leader)'"]
# ["'to waste time', 'examples': []}, {'gloss': 'to carry out duties in a non-commital fashion'"]
# ["'to treat sb. discourteously', 'examples': []}, {'gloss': 'to become shabby in appearance'"]
# ["'to become shabby in appearance', 'examples': []}, {'gloss': 'to fall on hard times', 'examples': []}, {'gloss': 'to make an error'"]
# ["'to anger sb.'"]
# ["'to be very upset or angry', 'examples': []}, {'gloss': 'to become overcast (used of the weather)'"]
# ["'to make a deafening noise', 'examples': []}, {'gloss': 'to beat sb. violently', 'examples': []}, {'gloss': 'to defeat sb. thoroughly (colloquial; e.g. in a sport)'"]
# ['"to be out of one\'s senses (e.g. due to excessive drinking)", \'examples\': []}, {\'gloss\': \'to be thoroughly defeated (e.g. in a sport)\', \'examples\': []}, {\'gloss\': \'to be filled with a deafening noise\', \'examples\': []}, {\'gloss\': \'to be deafened by loud noises\', \'examples\': []}, {\'gloss\': \'to become excessively fatigued\'']
# ["'to hang sth.', 'examples': []}, {'gloss': 'to execute sb. by hanging', 'examples': []}, {'gloss': 'to hand over sth. to sb. (colloquial, often used for the exchange of money)'"]
# ["'to be hung', 'examples': []}, {'gloss': 'to allow oneself to grow shabby'"]
# ["'to ring bells'"]
# ["'to show off', 'examples': []}, {'gloss': 'to swagger', 'examples': []}, {'gloss': 'to live or grow up in the lap of luxury'"]
# ["'to get worked up or excited'"]
# ['\'to make water murky\', \'examples\': []}, {\'gloss\': \'to annoy or disgust sb.\', \'examples\': []}, {\'gloss\': "to make sb.\'s stomach churn"']
# ["'to behave in an annoying or showy manner', 'examples': []}, {'gloss': 'to feel nausea'"]
# ["'to madden', 'examples': []}, {'gloss': 'to create mayhem'"]
# ['\'to go mad\', \'examples\': []}, {\'gloss\': "to lose one\'s mind"']
# ["'to walk slowly'"]
# ["'to curl', 'examples': []}, {'gloss': 'to grow red peppers'"]
# ['"to become curly (used of one\'s hair)"']
# ["'to fend', 'examples': []}, {'gloss': 'to get a word in', 'examples': []}, {'gloss': 'to roll a receptacle towards a mark (used in the context of a traditional game)'"]
# ["'to be rolled towards a mark (used in the context of a traditional game)'"]
# ["'to deepen', 'examples': []}, {'gloss': 'to plunge', 'examples': []}, {'gloss': 'to dive to the bottom', 'examples': []}, {'gloss': 'to cast liquid metal'"]
# ["'to dig out'"]
# ["'to act proudly', 'examples': []}, {'gloss': 'to strut or swagger'"]
# ["'to fake', 'examples': []}, {'gloss': 'to pretend'"]
# ["'to be boorish', 'examples': []}, {'gloss': 'to lament', 'examples': []}, {'gloss': 'to be hard to please'"]
# ["'to indulge in fantasy'"]
# ["'to become irritated', 'examples': []}, {'gloss': 'to take umbrage'"]
# ["'to shuffle along', 'examples': []}, {'gloss': 'to cause sb. to shuffle along'"]
# ["'to start shuffling'"]
# ["'to dust', 'examples': []}, {'gloss': 'to brush off'"]
# ["'to be dusted', 'examples': []}, {'gloss': 'to brush oneself down'"]
# ['\'to flutter\', \'examples\': []}, {\'gloss\': \'to be anxious\', \'examples\': []}, {\'gloss\': "to palpitate (used of one\'s heart)", \'examples\': []}, {\'gloss\': \'to cling on to life\'']
# ["'to be fluttered', 'examples': []}, {'gloss': 'to be anxious'"]
# ["'to do sth. hurriedly or rashly'"]
# ["'to get disconcerted'"]
# ["'to behave without restraint'"]
# ["'to stir coal or other fuel using a poker'"]
# ["'to be kindled or stirred with a poker'"]
# ['\'to scrape the ground\', \'examples\': []}, {\'gloss\': "to perform one\'s work in a disorderly fashion"']
# ["'to be scraped', 'examples': []}, {'gloss': 'to become disorderly'"]
# ["'to supply sb. with sth.'"]
# ["'to burn brightly'"]
# ["'to enrage', 'examples': []}, {'gloss': 'to drive sb. to a frenzy'"]
# ["'to be enraged', 'examples': []}, {'gloss': 'to be driven to a frenzy'"]
# ['"to wave one\'s hands", \'examples\': []}, {\'gloss\': \'to scurry about\'']
# ["'to blow (used of a strong wind)'"]
# ["'to grow bald', 'examples': []}, {'gloss': 'to trim the upper part of a tree or bush'"]
# ["'to grow bald'"]
# ["'to blush'"]
# ["'to drive to frenzy', 'examples': []}, {'gloss': 'to confuse'"]
# ["'to swathe', 'examples': []}, {'gloss': 'to wrap', 'examples': []}, {'gloss': 'to remove shell, husk or pod'"]
# ["'to swathe oneself (e.g. in warm clothes)', 'examples': []}, {'gloss': 'to be shelled'"]
# ["'to whisper', 'examples': []}, {'gloss': 'to gossip'"]
# ["'to be whispered'"]
# ["'to swaddle'"]
# ["'to swaddle oneself'"]
# ["'to speak indistinctly', 'examples': []}, {'gloss': 'to stutter'"]
# ["'to fizzle', 'examples': []}, {'gloss': 'to sizzle', 'examples': []}, {'gloss': 'to act in a confused manner'"]
# ["'to confuse', 'examples': []}, {'gloss': 'to thwart', 'examples': []}, {'gloss': 'to disrupt'"]
# ["'to stumble', 'examples': []}, {'gloss': 'to become confused'"]
# ["'to sing'"]
# ["'to do sth. without excelling', 'examples': []}, {'gloss': 'to scrape through', 'examples': []}, {'gloss': 'to just about manage'"]
# ["'to well up (used of tears)', 'examples': []}, {'gloss': 'to trickle down', 'examples': []}, {'gloss': 'to germinate'"]
# ["'to be made or allowed to trickle down', 'examples': []}, {'gloss': 'to become stronger', 'examples': []}, {'gloss': 'to germinate'"]
# ["'to weep copious tears'"]
# ["'to flow copiously (used especially of tears)'"]
# ["'to hit', 'examples': []}, {'gloss': 'to beat'"]
# ["'to treat sb. or sth. violently or harshly'"]
# ["'to join', 'examples': []}, {'gloss': 'to glue together'"]
# ["'to be joined', 'examples': []}, {'gloss': 'to be glued together'"]
# ["'to split', 'examples': []}, {'gloss': 'to crack', 'examples': []}, {'gloss': 'to shake vigorously'"]
# ["'to be cracked', 'examples': []}, {'gloss': 'to be broken', 'examples': []}, {'gloss': 'to be in a bad state (e.g. due to ill health or strenuous exercise causing exhaustion)'"]
# ["'to move aside'"]
# ["'to gnaw away at sth.'"]
# ["'to mumble', 'examples': []}, {'gloss': 'to mutter', 'examples': []}, {'gloss': 'to speak indistinctly'"]
# ["'to swarm', 'examples': []}, {'gloss': 'to gather in large numbers', 'examples': []}, {'gloss': 'to speak indistinctly'"]
# ["'to brush away the soil off vegetables or fruits'"]
# ["'to gush', 'examples': []}, {'gloss': 'to gurgle'"]
# ["'to become weak or unhealthy'"]
# ["'to grumble', 'examples': []}, {'gloss': 'to mumble', 'examples': []}, {'gloss': 'to mutter'"]
# ["'to bite'"]
# ["'to roll sth.', 'examples': []}, {'gloss': 'to elapse quickly (used especially of time)'"]
# ["'to roll', 'examples': []}, {'gloss': 'to turn over'"]
# ["'to damage sth.', 'examples': []}, {'gloss': 'to handle sth. roughly'"]
# ["'to be damaged', 'examples': []}, {'gloss': 'to be handled roughly'"]
# ["'to muddle', 'examples': []}, {'gloss': 'to create chaos', 'examples': []}, {'gloss': 'to make disorder'"]
# ["'to be discomposed', 'examples': []}, {'gloss': 'to be in disorder'"]
# ["'to babble', 'examples': []}, {'gloss': 'to prate', 'examples': []}, {'gloss': 'to sing (used of certain species of birds, especially plovers)'"]
# ["'to bellow (used especially of bovine animals)', 'examples': []}, {'gloss': 'to roar (like a lion)'"]
# ["'to complain', 'examples': []}, {'gloss': 'to grumble', 'examples': []}, {'gloss': 'to lament'"]
# ["'to be the subject of complaint'"]
# ["'to cause irritation or displeasure', 'examples': []}, {'gloss': 'to disgust', 'examples': []}, {'gloss': 'to offend', 'examples': []}, {'gloss': 'to disappoint'"]
# ["'to be disgusted', 'examples': []}, {'gloss': 'to be offended'"]
# ["'to spin round'"]
# ["'to be spun round'"]
# ["'to cover with soot', 'examples': []}, {'gloss': 'to make sth. scruffy or dirty'"]
# ["'to become covered with soot', 'examples': []}, {'gloss': 'to become scruffy'"]
# ["'to infect (especially with a disease)'"]
# ["'to talk nonsensically', 'examples': []}, {'gloss': 'to chatter'"]
# ["'to make dough without enough yeast', 'examples': []}, {'gloss': 'to stamp down on wet earth, causing it to harden'"]
# ["'to shiver'"]
# ["'to enjoy', 'examples': []}, {'gloss': 'to take pleasure in sth.', 'examples': []}, {'gloss': 'to have an orgasm'"]
# ["'to be enjoyed'"]
# ["'to become timid', 'examples': []}, {'gloss': 'to start avoiding society'"]
# ["'to suck on a comforter or the teat of a bottle'"]
# ["'to wrap', 'examples': []}, {'gloss': 'to swaddle'"]
# ["'to be wrapped', 'examples': []}, {'gloss': 'to be swaddled'"]
# ['"to disperse water with one\'s feet as one walks on a wet surface"']
# ["'to be splashed (said of water, usually on the floor or ground)'"]
# ['"to press with one\'s finger"']
# ["'to be pressed with a finger'"]
# ["'to regard', 'examples': []}, {'gloss': 'to eye', 'examples': []}, {'gloss': 'to look at'"]
# ["'to look at oneself'"]
# ["'to walk slowly', 'examples': []}, {'gloss': 'to loiter'"]
# ["'to loiter', 'examples': []}, {'gloss': 'to delay', 'examples': []}, {'gloss': 'to be very slow'"]
# ["'to crawl along', 'examples': []}, {'gloss': 'to move very slowly, like a snail'"]
# ["'to glisten with dew'"]
# ["'to yield fruit in bunches'"]
# ["'to yield bunches of fruit'"]
# ["'to fill with squills'"]
# ["'to become filled with squills'"]
# ["'to scrutinise', 'examples': []}, {'gloss': 'to sift', 'examples': []}, {'gloss': 'to examine', 'examples': []}, {'gloss': 'to ponder'"]
# ["'to be considered', 'examples': []}, {'gloss': 'to be examined', 'examples': []}, {'gloss': 'to be sifted'"]
# ["'to flood', 'examples': []}, {'gloss': 'to gurgle', 'examples': []}, {'gloss': 'to make a bubbling noise'"]
# ["'to become flooded'"]
# ['"to stamp on one\'s heel"']
# ["'to flit about (used of insects)', 'examples': []}, {'gloss': 'to swarm'"]
# ["'to strip sb.'"]
# ['"to take off one\'s clothes"']
# ["'to disappear', 'examples': []}, {'gloss': 'to fly away'"]
# ["'to become populated with birds'"]
# ["'to sprout twigs', 'examples': []}, {'gloss': 'to walk with the aid of a stick'"]
# ["'to sprout twigs'"]
# ["'to experience discomfort'"]
# ["'according to Aquilina, to cry hysterically like a child (possibly dialectal)'"]
# ["'to drive mad', 'examples': []}, {'gloss': 'to derange'"]
# ["'to go mad'"]
# ["'to rave', 'examples': []}, {'gloss': 'to mull sth. over'"]
# ["'to mull sth. over', 'examples': []}, {'gloss': 'to go mad'"]
# ["'to flicker (used of flames)'"]
# ["'to work diligently', 'examples': []}, {'gloss': 'to make an effort'"]
# ['\'to eat with gusto\', \'examples\': []}, {\'gloss\': "to feed one\'s young (used of animals or birds)"']
# ["'to be fed'"]
# ["'to make an effort', 'examples': []}, {'gloss': 'to get into action'"]
# ["'to swish or rustle'"]
# ["'to reduce density'"]
# ["'to have density reduced', 'examples': []}, {'gloss': 'to liquify', 'examples': []}, {'gloss': 'to go soft'"]
# ["'to argue vehemently', 'examples': []}, {'gloss': 'to talk loudly'"]
# ["'to argue vehemently', 'examples': []}, {'gloss': 'to talk loudly'"]
# ['"to speak through one\'s nose"']
# ["'to get flustered'"]
# ["'to press sb. tightly against sth. or sb.', 'examples': []}, {'gloss': 'to fit sth. in a tight place'"]
# ["'to press oneself tightly against sth. or sb.', 'examples': []}, {'gloss': 'to fit tightly between two things'"]
# ["'to eat with gusto'"]
# ["'to mess up a piece of work due to excessive haste'"]
# ["'to be messed up (typically used of a job or task)', 'examples': []}, {'gloss': 'to go dry (used of grass)'"]
# ["'to fall into ruin (used of buildings)'"]
# ["'to rustle', 'examples': []}, {'gloss': 'to swish', 'examples': []}, {'gloss': 'to whisper'"]
# ["'to be rustled', 'examples': []}, {'gloss': 'to be shaken out (used of a mattress, a straw mat, etc)'"]
# ["'to shake very thoroughly', 'examples': []}, {'gloss': 'to quake'"]
# ["'to be shaky'"]
# ["'to grind or pound'"]
# ["'to be entrenched', 'examples': []}, {'gloss': 'to dig oneself in'"]
# ["'to irritate'"]
# ["'to be irritated'"]
# ["'to speak nasally'"]
# ["'to take root', 'examples': []}, {'gloss': 'to grow small roots'"]
# ["'to develop small roots'"]
# ["'to slash', 'examples': []}, {'gloss': 'to sever', 'examples': []}, {'gloss': 'to strum an instrument roughly', 'examples': []}, {'gloss': 'to speak very loudly', 'examples': []}, {'gloss': 'to scream'"]
# ["'to be slashed'"]
# ["'to dirty', 'examples': []}, {'gloss': 'to besmirch', 'examples': []}, {'gloss': 'to carry out sth. very roughly'"]
# ["'to over-eat', 'examples': []}, {'gloss': 'to pig out'"]
# ["'to devastate', 'examples': []}, {'gloss': 'to put in disorder'"]
# ["'to be put out of joint', 'examples': []}, {'gloss': 'to be disarrayed', 'examples': []}, {'gloss': 'to be ruined'"]
# ["'to scribble', 'examples': []}, {'gloss': 'to doodle'"]
# ["'to be scribbled'"]
# ["'to scrape around', 'examples': []}, {'gloss': 'to claw at the earth'"]
# ["'to do shoddy work'"]
# ["'to be done in a shoddy manner'"]
# ["'to breathe heavily', 'examples': []}, {'gloss': 'to purr'"]
# ["'to have a rattling breath', 'examples': []}, {'gloss': 'to breathe heavily'"]
# ["'to sound hollow'"]
# ["'to stir'"]
# ["'to slap sb. in the face'"]
# ["'to roll sth.', 'examples': []}, {'gloss': 'to roll sth. down an inclined plane'"]
# ["'to roll (especially in the dust or down an incline)'"]
# ["'to perform duties in the kitchen'"]
# ["'to speak indistinctly'"]
# ["'to become ruffled'"]
# ["'to mistreat', 'examples': []}, {'gloss': 'to misuse', 'examples': []}, {'gloss': 'to damage through misuse or overuse'"]
# ["'to be mistreated', 'examples': []}, {'gloss': 'to be misused', 'examples': []}, {'gloss': 'to wear out due to overuse', 'examples': []}, {'gloss': 'to be exhausted due to physical effort'"]
# ["'to cause to writhe (e.g. in pain or laughter)'"]
# ["'to writhe (due to pain, laughter etc.)'"]
# ["'to coil', 'examples': []}, {'gloss': 'to take the shape of a coil'"]
# ["'to just about manage', 'examples': []}, {'gloss': 'to get by', 'examples': []}, {'gloss': 'to get through a difficult situation'"]
# ["'to continue sth.'"]
# ["'to be continued'"]
# ["'to have a room mate', 'examples': []}, {'gloss': 'to live with sb.'"]
# ["'to shade (used of colours which shade into other colours)'"]
# ["'to sing'"]
# ["'to be sung'"]
# ["'to cover', 'examples': []}, {'gloss': 'to account for'"]
# ["'to be covered', 'examples': []}, {'gloss': 'to be accounted for'"]
# ["'to chill', 'examples': []}, {'gloss': 'to be very cold'"]
# ["'to be chilled'"]
# ["'to hobble along'"]
# ["'to develop evil ways'"]
# ["'to drag', 'examples': []}, {'gloss': 'to draw out'"]
# ["'to be dragged', 'examples': []}, {'gloss': 'to be drawn out'"]
# ["'to sing (used especially of certain species of birds)'"]
# ["'to live on modest means'"]
# ["'to leave a tart taste in the mouth'"]
# ["'to wither or shrink (used especially of certain types of fruit)'"]
# ['"to be unfaithful to one\'s partner or spouse (lit. to raise horns)"']
# ["'to rumble (used of thunder)', 'examples': []}, {'gloss': 'to grind'"]
# ["'to rumble', 'examples': []}, {'gloss': 'to be ground'"]
# ['"to walk in one\'s slippers"']
# ["'to mistreat', 'examples': []}, {'gloss': 'to oppress'"]
# ["'to be oppressed'"]
# ["'to instigate', 'examples': []}, {'gloss': 'to foment trouble'"]
# ["'to be instigated', 'examples': []}, {'gloss': 'to be angered'"]
# ['"to idle away one\'s time doing something of no importance"']
# ["'to make a cackling sound (e.g. as chickens do)', 'examples': []}, {'gloss': 'to attract fowls when preparing their food'"]
# ['"to make up excuses to avoid doing one\'s work"']
# ["'to become strewn with stars'"]
# ["'to become strewn with stars'"]
# ["'to make a hash of things', 'examples': []}, {'gloss': 'to confuse things', 'examples': []}, {'gloss': 'to mess up'"]
# ["'to become messed up'"]
# ["'to make excuses'"]
# ["'to drag', 'examples': []}, {'gloss': 'to trounce', 'examples': []}, {'gloss': 'to defeat dramatically (e.g. at sport or in a poll)'"]
# ["'to drag oneself along', 'examples': []}, {'gloss': 'to be dragged', 'examples': []}, {'gloss': 'to be trounced'"]
# ["'to make sb. tremble with fear', 'examples': []}, {'gloss': 'to terrify'"]
# ["'to become terrified', 'examples': []}, {'gloss': 'to tremble with fear'"]
# ["'to rummage in search of sth.'"]
# ["'to talk a lot', 'examples': []}, {'gloss': 'to chatter'"]
# ["'to make sb. crave sth.', 'examples': []}, {'gloss': 'to inspire a craving'"]
# ["'to experience a craving'"]
# ["'to eat greedily', 'examples': []}, {'gloss': 'to wolf down', 'examples': []}, {'gloss': 'to scoff food'"]
# ["'to be  wolfed down'"]
# ["'to guzzle', 'examples': []}, {'gloss': 'to drink in gulps', 'examples': []}, {'gloss': 'to down a drink'"]
# ["'to be guzzled'"]
# ["'to have a speech defect'"]
# ["'to rinse'"]
# ["'to rinse onself'"]
# ["'to pour through a funnel'"]
# ["'to be spread with a rolling pin'"]
# ["'to spread with a rolling pin'"]
# ["'to rain heavily'"]
# ["'to bristle'"]
# ["'to become bristly'"]
# ["'to stammer', 'examples': []}, {'gloss': 'to stutter', 'examples': []}, {'gloss': 'to hesitate'"]
# ["'to finish', 'examples': []}, {'gloss': 'to complete'"]
# ["'to be finished'"]
# ["'to poke the tongue out (used especially of a snake)', 'examples': []}, {'gloss': 'to lap at sth.'"]
# ['"to smack one\'s lips or make noise while chewing"']
# ["'to mumble', 'examples': []}, {'gloss': 'to speak indistinctly'"]
# ["'to act like a mad person'"]
# ["'to beat about the bush', 'examples': []}, {'gloss': 'to avoid directness', 'examples': []}, {'gloss': 'to make a point by analogy or metaphor'"]
# ["'to rub vigorously', 'examples': []}, {'gloss': 'to scour'"]
# ["'to mutter'"]
# ["'to mutter'"]
# ["'to sharpen', 'examples': []}, {'gloss': 'to whet', 'examples': []}, {'gloss': 'to hone'"]
# ["'to be honed'"]
# ["'to quiet down', 'examples': []}, {'gloss': 'to calm down', 'examples': []}, {'gloss': 'to die down'"]
# ["'to munch', 'examples': []}, {'gloss': 'to masticate', 'examples': []}, {'gloss': 'to make sounds while chewing'"]
# ["'to make a mess'"]
# ["'to be messed up', 'examples': []}, {'gloss': 'to be squandered'"]
# ["'to act in an evil manner'"]
# ["'to support financially', 'examples': []}, {'gloss': 'to bring up', 'examples': []}, {'gloss': 'to maintain'"]
# ["'to be supported', 'examples': []}, {'gloss': 'to be maintained'"]
# ["'to render weak and infirm'"]
# ["'to become weak and infirm'"]
# ["'to lug a heavy burden (esp. stones)'"]
# ["'to heap', 'examples': []}, {'gloss': 'to stack'"]
# ["'to be heaped', 'examples': []}, {'gloss': 'to be stacked'"]
# ["'to find fault', 'examples': []}, {'gloss': 'to put down', 'examples': []}, {'gloss': 'to criticise'"]
# ["'to be criticised', 'examples': []}, {'gloss': 'to be put down'"]
# ["'to grumble and mutter angrily', 'examples': []}, {'gloss': 'to mope'"]
# ["'to arrange in layers'"]
# ["'to be arranged in layers'"]
# ["'to form a scar after healing (used of wounds)'"]
# ["'to complain', 'examples': []}, {'gloss': 'to whine'"]
# ["'to decay', 'examples': []}, {'gloss': 'to rot', 'examples': []}, {'gloss': 'to erode'"]
# ["'to decay', 'examples': []}, {'gloss': 'to rot', 'examples': []}, {'gloss': 'to erode'"]
# ["'to hit with a hammer'"]
# ["'to be hit with a hammer'"]
# ["'to flash', 'examples': []}, {'gloss': 'to emit rays', 'examples': []}, {'gloss': 'to radiate'"]
# ["'to flash', 'examples': []}, {'gloss': 'to emit rays', 'examples': []}, {'gloss': 'to radiate'"]
# ["'to cause to anger', 'examples': []}, {'gloss': 'to make sb. see red'"]
# ["'to become angry', 'examples': []}, {'gloss': 'to become vexed'"]
# ["'to scold', 'examples': []}, {'gloss': 'to give a tongue-lashing'"]
# ["'to scold thoroughly', 'examples': []}, {'gloss': 'to be very angry at sb.', 'examples': []}, {'gloss': 'to express contempt for sb.'"]
# ["'to have pity', 'examples': []}, {'gloss': 'to express compassion or empathy'"]
# ["'to inspire pity'"]
# ["'to be wiped vigorously', 'examples': []}, {'gloss': 'to be smeared'"]
# ["'to change places constantly'"]
# ["'to gnaw'"]
# ["'to be gnawed'"]
# ['\'to eat a lot\', \'examples\': []}, {\'gloss\': \'to wolf down\', \'examples\': []}, {\'gloss\': "to chomp one\'s food"']
# ["'to be wolfed down', 'examples': []}, {'gloss': 'to be eaten in large quantities'"]
# ["'to damage', 'examples': []}, {'gloss': 'to use clumsily'"]
# ["'to nibble listlessly at food', 'examples': []}, {'gloss': 'to drive sb. off', 'examples': []}, {'gloss': 'to inspire repugnance'"]
# ["'to be driven off', 'examples': []}, {'gloss': 'to feel repugnance at sth. or sb.'"]
# ['"to speak through one\'s nose"']
# ["'to flicker (esp. used of a flame, as on a candle or lamp)'"]
# ["'to croak', 'examples': []}, {'gloss': 'to speak in a deep or gravelly voice'"]
# ['\'to irritate\', \'examples\': []}, {\'gloss\': "to get on sb.\'s nerves"']
# ["'to become irritable'"]
# ["'to sniff reepatedly', 'examples': []}, {'gloss': 'to have a running nose'"]
# ["'to prattle', 'examples': []}, {'gloss': 'to chatter', 'examples': []}, {'gloss': 'to gossip'"]
# ["'to talk', 'examples': []}, {'gloss': 'to chatter', 'examples': []}, {'gloss': 'to gossip'"]
# ['"to strain one\'s eyes", \'examples\': []}, {\'gloss\': \'to blink repeatedly\'']
# ['\'to blink repeatedly\', \'examples\': []}, {\'gloss\': "to straing one\'s eyes"']
# ["'to make sth. flabby'"]
# ["'to become flabby'"]
# ["'to sing (used of certain types of birds)'"]
# ["'to handle objects from among which one chooses (e.g. objects on display in a shop)'"]
# ["'to paint', 'examples': []}, {'gloss': 'to draw', 'examples': []}, {'gloss': 'to tattoo', 'examples': []}, {'gloss': 'to depict'"]
# ["'to be painted', 'examples': []}, {'gloss': 'to be drawn', 'examples': []}, {'gloss': 'to be tattooed'"]
# ["'to paint with a brush'"]
# ["'to satisfy a whim', 'examples': []}, {'gloss': 'to have a foolish idea'"]
# ["'to honk a car horn'"]
# ["'to grow lethargic', 'examples': []}, {'gloss': 'to exhibit lassitude'"]
# ["'to grow lethargic', 'examples': []}, {'gloss': 'to experience lassitude'"]
# ["'to speak', 'examples': []}, {'gloss': 'to talk a lot', 'examples': []}, {'gloss': 'to chatter'"]
# ["'to put in layers'"]
# ["'to make off', 'examples': []}, {'gloss': 'to flee', 'examples': []}, {'gloss': 'to make oneself scarce'"]
# ["'to billow (e.g. of a flag in the wind)', 'examples': []}, {'gloss': 'to hang (used especially of clothes on a line)'"]
# ["'to billow (e.g. of a flag in the wind)', 'examples': []}, {'gloss': 'to hang (used especially of clothes on a line)'"]
# ["'to leave', 'examples': []}, {'gloss': 'to depart'"]
# ["'to exchange sth.'"]
# ["'to be exchanged'"]
# ["'to make sth. floppy or flabby'"]
# ["'to become flabby and loose (used especially of skin in old age)'"]
# ["'to act on the fly', 'examples': []}, {'gloss': 'to make things up'"]
# ["'to be made up on the fly', 'examples': []}, {'gloss': 'to be invented'"]
# ["'to whisper', 'examples': []}, {'gloss': 'to chirp (used of young birds)'"]
# ['\'to be whispered\', \'examples\': []}, {\'gloss\': "to be hissed in sb.\'s ear"']
# ["'to pretend to be sb. else', 'examples': []}, {'gloss': 'to be an impostor'"]
# ['\'to behave rudely\', \'examples\': []}, {\'gloss\': \'to speak in a vulgar manner\', \'examples\': []}, {\'gloss\': "to be sb.\'s lackey"']
# ["'to behave rudely', 'examples': []}, {'gloss': 'to speak in a vulgar manner'"]
# ["'to chatter', 'examples': []}, {'gloss': 'to prattle', 'examples': []}, {'gloss': 'to gossip'"]
# ["'to blink', 'examples': []}, {'gloss': 'to flicker (used of flames or a light)'"]
# ["'to require a certain depth (used of ships)'"]
# ["'to turn flabby'"]
# ["'to urinate', 'examples': []}, {'gloss': 'to pee'"]
# ["'to use a place as a habitat (used especially of birds)'"]
# ["'to chirp (used of young birds when they begin to sing)'"]
# ["'to have a great time', 'examples': []}, {'gloss': 'to play and gambol'"]
# ["'to have a good time', 'examples': []}, {'gloss': 'to play around', 'examples': []}, {'gloss': 'to gambol'"]
# ["'to weave baskets'"]
# ["'to cough intermittently'"]
# ["'to seal or waterproof', 'examples': []}, {'gloss': 'to throw sb. out of a place'"]
# ["'to be sealed or waterproofed', 'examples': []}, {'gloss': 'to be thrown out of a place'"]
# ["'to grumble constantly'"]
# ["'to be thrifty', 'examples': []}, {'gloss': 'to be economical', 'examples': []}, {'gloss': 'to save'"]
# ["'to be saved', 'examples': []}, {'gloss': 'to be economised'"]
# ["'to lug', 'examples': []}, {'gloss': 'to carry sth. heavy'"]
# ["'to be lugged', 'examples': []}, {'gloss': 'to be carried (used of a heavy object)'"]
# ["'to tousle', 'examples': []}, {'gloss': 'to muss'"]
# ["'to get mussed', 'examples': []}, {'gloss': 'to get scruffy'"]
# ["'to measure water depth using a weight'"]
# ["'to excite', 'examples': []}, {'gloss': 'to agitate', 'examples': []}, {'gloss': 'to arouse', 'examples': []}, {'gloss': 'to provoke'"]
# ["'to be excited', 'examples': []}, {'gloss': 'to be agitated', 'examples': []}, {'gloss': 'to be provoked', 'examples': []}, {'gloss': 'to be aroused'"]
# ["'to live frugally'"]
# ["'to be heavy'"]
# ["'to exert oneself too much', 'examples': []}, {'gloss': 'to do sth. with great reluctance or difficulty', 'examples': []}, {'gloss': 'to mess up a task'"]
# ["'to over-exert onseself', 'examples': []}, {'gloss': 'to try too hard at doing sth.'"]
# ["'to give communion during a Catholic mass', 'examples': []}, {'gloss': 'to feed sb. very little (used figuratively)'"]
# ["'to take communion during mass', 'examples': []}, {'gloss': 'to eat very little'"]
# ['"to comb one\'s hair"']
# ['"to have one\'s hair curled"']
# ["'to check the growth of plants', 'examples': []}, {'gloss': 'to stunt'"]
# ['"to have one\'s growth checked", \'examples\': []}, {\'gloss\': \'to be stunted\'']
# ["'to separate the fibres (of wool or other thread)'"]
# ["'to have fibres separated'"]
# ['"to crunch between one\'s teeth"']
# ["'to be crunched'"]
# ["'to put up with sb. or sth.', 'examples': []}, {'gloss': 'to grow feathers (used of birds)'"]
# ["'to become reluctant to engage in sth.'"]
# ["'to singe (e.g. while roasting food)', 'examples': []}, {'gloss': 'to grow stiff and crack (e.g. in the sun)'"]
# ["'to grow stiff and crack', 'examples': []}, {'gloss': 'to become singed', 'examples': []}, {'gloss': 'to become mischievous or naughty'"]
# ["'to lop off the top (of a plant or shrub)', 'examples': []}, {'gloss': 'to shear'"]
# ["'to be cut off'"]
# ["'to shear (used of plants or shrubs)'"]
# ["'to be sheared'"]
# ["'to wrap in paper'"]
# ["'to be wrapped in paper'"]
# ["'to clip (used of hair)', 'examples': []}, {'gloss': 'to get a close-cropped haircut', 'examples': []}, {'gloss': 'to shear an animal'"]
# ["'to get sheared', 'examples': []}, {'gloss': 'to get cut very short (used of hair)'"]
# ["'to buff (used of metal)', 'examples': []}, {'gloss': 'to burnish'"]
# ["'to be buffed', 'examples': []}, {'gloss': 'to be burnished'"]
# ["'to clip-clop'"]
# ["'to clip-clop'"]
# ["'to form a crust', 'examples': []}, {'gloss': 'to harden'"]
# ["'to harden', 'examples': []}, {'gloss': 'to dry (e.g. used of vegetables which are ready to be shelled)'"]
# ["'to dry completely', 'examples': []}, {'gloss': 'to drain'"]
# ["'to become dry', 'examples': []}, {'gloss': 'to be drained'"]
# ["'to make a grunting sound (like a pig)'"]
# ["'the making of a grunting sound'"]
# ["'to give out sth. sparingly'"]
# ["'to talk a lot', 'examples': []}, {'gloss': 'to chatter'"]
# ["'to roll sth. along', 'examples': []}, {'gloss': 'to make a roll (e.g. in rolling a  cigarette)'"]
# ["'to be rolled', 'examples': []}, {'gloss': 'to roll along'"]
# ["'to hook (especially a bucket to be lowered into a well)', 'examples': []}, {'gloss': 'to fish for squid or octopus using an octopus pot'"]
# ["'to be hooked'"]
# ["'to ring'"]
# ["'to be rung'"]
# ["'to be arranged', 'examples': []}, {'gloss': 'to be set straight', 'examples': []}, {'gloss': 'to be rectified or resolved'"]
# ["'to make rancid'"]
# ["'to go rancid'"]
# ["'to string onions, fish, etc. together'"]
# ["'to suck liquid (e.g. through a straw)'"]
# ["'to be sucked in'"]
# ["'to serve'"]
# ["'to become overgrown with thyme'"]
# ["'to pry', 'examples': []}, {'gloss': 'to be inquisitive'"]
# ["'to binge on alcohol'"]
# ["'to gossip', 'examples': []}, {'gloss': 'to pry'"]
# ["'to be gossiped about'"]
# ["'to link up in a chain', 'examples': []}, {'gloss': 'to string together'"]
# ["'to leave harbour (used of ships)', 'examples': []}, {'gloss': 'to raise anchor'"]
# ["'to reign'"]
# ["'to save sb.', 'examples': []}, {'gloss': 'to rescue', 'examples': []}, {'gloss': 'to redeem'"]
# ["'to be saved', 'examples': []}, {'gloss': 'to be rescued'"]
# ["'to solve', 'examples': []}, {'gloss': 'to figure out'"]
# ["'to be solved'"]
# ["'to scrape'"]
# ["'to gather in succession (used especially of clouds)'"]
# ["'to rake'"]
# ["'to be raked'"]
# ['"to curse as a result of losing one\'s temper"']
# ["'to put off doing something'"]
# ["'to give away a secret', 'examples': []}, {'gloss': 'to act as a go-between'"]
# ["'to be divulged (to become the object of gossip)', 'examples': []}, {'gloss': 'to be mediated by a broker'"]
# ["'to hoard goods or money'"]
# ['"occurs in the expression expression \'qata\' sandar\', said of sb. who makes a bad deal or embarrasses themself"']
# ["'to make a mess of sth.'"]
# ["'to string together', 'examples': []}, {'gloss': 'to chain', 'examples': []}, {'gloss': 'to give rise to'"]
# ["'to be strung together', 'examples': []}, {'gloss': 'to be linked up in a chain', 'examples': []}, {'gloss': 'to be put in sequence'"]
# ["'to act as a go-between', 'examples': []}, {'gloss': 'to sell real estate on behalf of a client or firm'"]
# ["'to soap'"]
# ["'to ask', 'examples': []}, {'gloss': 'to inquire', 'examples': []}, {'gloss': 'to seek information'"]
# ["'to put in a row or queue'"]
# ["'to be put in a row'"]
# ["'to shift sth. heavy'"]
# ["'to be made untidy as a result of being handled (said of a young child)'"]
# ["'to adopt a haughty manner'"]
# ["'to adopt a haughty manner'"]
# ["'to lie at anchor', 'examples': []}, {'gloss': 'to sit down'"]
# ["'to tangle', 'examples': []}, {'gloss': 'to entwine'"]
# ["'to darn', 'examples': []}, {'gloss': 'to sew in a zigzag'"]
# ["'to chatter', 'examples': []}, {'gloss': 'to blather'"]
# ["'to serve', 'examples': []}, {'gloss': 'to be appropriate for sth.'"]
# ["'to serve oneself', 'examples': []}, {'gloss': 'to help oneself', 'examples': []}, {'gloss': 'to use the loo (a euphemistic usage)'"]
# ["'to drag sb. into an issue', 'examples': []}, {'gloss': 'to make up false information', 'examples': []}, {'gloss': 'to wear pantaloons or baggy trousers'"]
# ["'to wear baggy trousers'"]
# ["'to nibble', 'examples': []}, {'gloss': 'to eat very lightly', 'examples': []}, {'gloss': 'to handle sth. using the tips of the fingers'"]
# ["'to be handled using fingers'"]
# ["'to speak hesitantly (especially in public)', 'examples': []}, {'gloss': 'to stammer'"]
# ["'to cough'"]
# ["'to tap', 'examples': []}, {'gloss': 'to tick (e.g. a clock)', 'examples': []}, {'gloss': 'to simmer (used in a culinary context)'"]
# ["'to be tapped', 'examples': []}, {'gloss': 'to be allowed to simmer (used in a culinary context)'"]
# ["'to stammer', 'examples': []}, {'gloss': 'to stutter'"]
# ["'to start stuttering'"]
# ["'to beat the drum', 'examples': []}, {'gloss': 'to make a crashing noise'"]
# ["'to be beaten (used of a drum)'"]
# ["'to soften', 'examples': []}, {'gloss': 'to fray (e.g. fabric or rope)'"]
# ["'to be softened (especially used of cushions etc)'"]
# ["'to strum'"]
# ["'to tinkle', 'examples': []}, {'gloss': 'to clink'"]
# ["'to fray'"]
# ["'to become frayed'"]
# ["'to patter', 'examples': []}, {'gloss': 'to tap'"]
# ["'to develop (used, e.g. of an affair, argument, narrative etc.)', 'examples': []}, {'gloss': 'to take a particular turn (used, e.g. of an affair, argument, narrative etc.)'"]
# ["'to rise to the surface of the water', 'examples': []}, {'gloss': 'to be worthwhile'"]
# ["'to succeed', 'examples': []}, {'gloss': 'to surmount a problem'"]
# ["'to be surmounted'"]
# ["'to howl (used of the wind)', 'examples': []}, {'gloss': 'to throw sth. with great force'"]
# ["'to be thrown with force'"]
# ["'to vary', 'examples': []}, {'gloss': 'to improvise (on an instrument)'"]
# ["'to be varied'"]
# ["'to give sb. a fright'"]
# ["'to blink'"]
# ['\'to chatter\', \'examples\': []}, {\'gloss\': \'to prattle\', \'examples\': []}, {\'gloss\': \'to make a clucking or croaking sound\', \'examples\': []}, {\'gloss\': "to palpitate (used of one\'s heart)"']
# ["'to work a lathe'"]
# ["'to shred', 'examples': []}, {'gloss': 'to tear to pieces', 'examples': []}, {'gloss': 'to reduce to tatters'"]
# ["'to be shredded', 'examples': []}, {'gloss': 'to be torn to pieces', 'examples': []}, {'gloss': 'to be in tatters'"]
# ["'to shiver with cold', 'examples': []}, {'gloss': 'to shudder'"]
# ["'to be made to shiver'"]
# ["'to make a whirring sound'"]
# ["'to jabber', 'examples': []}, {'gloss': 'to speak inarticulately'"]
# ["'to hiss', 'examples': []}, {'gloss': 'to make a hissing sound'"]
# ['"to echo persistently in sb.\'s ear"']
# ["'to sing (used of certain types of birds)'"]
# ["'to howl in pain'"]
# ["'to yack or caw (as certain birds, such as crows, do)'"]
# ["'to hum persistently', 'examples': []}, {'gloss': 'to howl (used of an alarm bell or air raid alarm)'"]
# ["'to scare', 'examples': []}, {'gloss': 'to dismay', 'examples': []}, {'gloss': 'to upset'"]
# ["'to be scared'"]
# ["'to scream', 'examples': []}, {'gloss': 'to shriek'"]
# ["'to whisper', 'examples': []}, {'gloss': 'to mutter'"]
# ["'to sing (used of certain types of birds)', 'examples': []}, {'gloss': 'to chatter'"]
# ["'to hoot (used of owls etc.)'"]
# ["'to arouse resentment', 'examples': []}, {'gloss': 'to evince bigotry (especially religious)'"]
# ["'to feel hurt', 'examples': []}, {'gloss': 'to bear a grudge'"]
# ["'to sprawl', 'examples': []}, {'gloss': 'to spread over a surface (used of plants such as wall-climbers)'"]
# ["'to sprawl', 'examples': []}, {'gloss': 'to spread along a surface (especially of plants, such as wall-climbers)'"]
# ["'to get cosy', 'examples': []}, {'gloss': 'to tuck (into bed)'"]
# ["'to get cosy', 'examples': []}, {'gloss': 'to luxuriate (esp. in bed)', 'examples': []}, {'gloss': 'to tuck oneself (into bed)'"]
# ["'to curse by invoking the devil'"]
# ["'to indulge in cursing by invoking the devil', 'examples': []}, {'gloss': 'to become possessed', 'examples': []}, {'gloss': 'to become evil'"]
# ["'to startle or frighten'"]
# ["'to sell at reduced prices', 'examples': []}, {'gloss': 'to undervalue'"]
# ["'to advertise', 'examples': []}, {'gloss': 'to publicise', 'examples': []}, {'gloss': 'to broadcast', 'examples': []}, {'gloss': 'to circulate', 'examples': []}, {'gloss': 'to reveal'"]
# ["'to be broadcast', 'examples': []}, {'gloss': 'to be advertised'"]
# ["'to sway', 'examples': []}, {'gloss': 'to lean'"]
# ["'to sway', 'examples': []}, {'gloss': 'to lean', 'examples': []}, {'gloss': 'to wobble'"]
# ["'to take root'"]
# ["'to take root'"]
# ["'to lean', 'examples': []}, {'gloss': 'to be inclined towards sth (e.g. a particular political view)'"]
# ["'to be made to lean towards sth.', 'examples': []}, {'gloss': 'to be made to incline towards a view or position'"]
# ["'to stain (especially with blood)'"]
# ["'to be stained or smeared (usually with blood)'"]
# ["'to throw forcefully'"]
# ["'to be thrown forcefully'"]
# ["'to vilify', 'examples': []}, {'gloss': 'to pour scorn'"]
# ["'to be vilified', 'examples': []}, {'gloss': 'to be scorned'"]
# ["'to make an oozing noise'"]
# ["'to make a buzzing or oozing noise'"]
# ["'to wiggle', 'examples': []}, {'gloss': 'to sway'"]
# ["'to wiggle', 'examples': []}, {'gloss': 'to be made to wiggle'"]
# ["'to wobble (like a spinning top)'"]
# ["'to wobble (like a spinning top)'"]
# ["'to manifest ostentatious behaviour'"]
# ["'to frolic', 'examples': []}, {'gloss': 'to skip around'"]
# ["'to dye with saffron or with a yellow colour'"]
# ["'to cover with thin or soft hair'"]
# ["'to become covered with thin or soft hair'"]
# ["'to sing (used of certain types of birds)', 'examples': []}, {'gloss': 'to use vulgar language'"]
# ["'to thunder'"]
# ["'to swell', 'examples': []}, {'gloss': 'to distend'"]
# ["'to drink a lot of alcohol'"]
# ["'to drink a lot of alcohol'"]
# ['"to play the \'żambura\', a traditional folk instrument"']
# ["'to pelt with rain', 'examples': []}, {'gloss': 'to pick fruit and put it in a basket'"]
# ["'to rock (e.g. a child in a cradle)'"]
# ["'to be rocked'"]
# ["'to play tunelessly'"]
# ["'to fatten'"]
# ["'to become plump'"]
# ["'to chop'"]
# ["'to be chopped'"]
# ["'to fatten', 'examples': []}, {'gloss': 'to make plump'"]
# ["'to grow fat'"]
# ["'to slaughter', 'examples': []}, {'gloss': 'to butcher', 'examples': []}, {'gloss': 'to disfigure', 'examples': []}, {'gloss': 'to ruin'"]
# ["'to be slaughtered', 'examples': []}, {'gloss': 'to be disfigured'"]
# ["'to overflow', 'examples': []}, {'gloss': 'to pour'"]
# ["'to be made to overflow', 'examples': []}, {'gloss': 'to be spilled'"]
# ["'to change sth', 'examples': []}, {'gloss': 'to alter sth'"]
# ['\'to change sth\', \'examples\': []}, {\'gloss\': \'to alter sth\', \'examples\': []}, {\'gloss\': "to change one\'s clothes"']
# ["'to be changed', 'examples': []}, {'gloss': 'to be exchanged'"]
# ["'to change', 'examples': []}, {'gloss': 'to be changed', 'examples': []}, {'gloss': 'to be exchanged'"]
# ["'to mitigate', 'examples': []}, {'gloss': 'to tone down', 'examples': []}, {'gloss': 'to exempt', 'examples': []}, {'gloss': 'to protect'"]
# ["'to be mitigated'"]
# ["'to become civil (e.g. following an outburst)'"]
# ["'to hate', 'examples': []}, {'gloss': 'to detest', 'examples': []}, {'gloss': 'to loathe', 'examples': []}, {'gloss': 'to dislike'"]
# ["'to cause hatred'"]
# ["'to cause to hate'"]
# ["'to experience mutual hatred'"]
# ["'to be hated', 'examples': []}, {'gloss': 'to be disliked', 'examples': []}, {'gloss': 'to be shunned'"]
# ["'to keep sth or sb at a distance', 'examples': []}, {'gloss': 'to avert'"]
# ['"to keep one\'s distance", \'examples\': []}, {\'gloss\': \'to hold at a distance\'']
# ["'to cause to interbreed'"]
# ["'to degenerate'"]
# ["'to degenerate', 'examples': []}, {'gloss': 'to interbreed (used of plants)', 'examples': []}, {'gloss': 'to grow lots of leaves (used of plants)', 'examples': []}, {'gloss': 'to work to hard'"]
# ['\'to send\', \'examples\': []}, {\'gloss\': \'to dismiss\', \'examples\': []}, {\'gloss\': "to discharge from one\'s duties", \'examples\': []}, {\'gloss\': \'to fire\'']
# ["'to be sent'"]
# ["'to make sth or sb resemble an animal'"]
# ["'to start behaving in an animal-like or beastly fashion'"]
# ["'to behave in an animal-like or beastly fashion'"]
# ["'to be emptied', 'examples': []}, {'gloss': 'to become void', 'examples': []}, {'gloss': 'to become desolate'"]
# ["'to reconnoitre (According to Aquilina, this word is only attested in the novel Ineż Farruġ by Anton Manwel Caruana, and is of indeterminate meaning)'"]
# ["'to fumigate', 'examples': []}, {'gloss': 'to exorcise using the fumes from olive branches'"]
# ["'to be fumigated'"]
# ["'to sail', 'examples': []}, {'gloss': 'to navigate the ocean'"]
# ["'to be navigated'"]
# ["'to bad-mouth', 'examples': []}, {'gloss': 'to slander', 'examples': []}, {'gloss': 'to make insinuations'"]
# ["'to spread slander', 'examples': []}, {'gloss': 'to calumniate'"]
# ["'to be bad-mouthed', 'examples': []}, {'gloss': 'to be slandered'"]
# ["'to become mute'"]
# ["'to dumbfound sb', 'examples': []}, {'gloss': 'to stupefy sb', 'examples': []}, {'gloss': 'to upset sb intensely'"]
# ["'to be dumbfounded', 'examples': []}, {'gloss': 'to be left speechless', 'examples': []}, {'gloss': 'to become mute'"]
# ["'to anticipate', 'examples': []}, {'gloss': 'to be among the first', 'examples': []}, {'gloss': 'to yield the first fruit of the season'"]
# ["'to rise early', 'examples': []}, {'gloss': 'to get an early start'"]
# ["'to be made to rise early'"]
# ['"hypothetical first form of \'bekket\' meaning \'to beat\'"']
# ["'to hit', 'examples': []}, {'gloss': 'to beat'"]
# ["'to be struck', 'examples': []}, {'gloss': 'to be beaten'"]
# ["'to swallow', 'examples': []}, {'gloss': 'to wolf down food', 'examples': []}, {'gloss': 'to believe believe what one is told (suggesting gullibility)'"]
# ...
# ["'a scrape'"]
# ["'Plate-rack', 'examples': []}, {'gloss': 'A kind of small wooden gate which separates on side from another'"]
# ["'sb. who cards'"]
# ['\'sb. who sucks in\', \'examples\': []}, {\'gloss\': "sb. who whispers into people\'s ears"']
# ["'tending to make a sucking noise'"]
# ["'a pipe'"]
# ["'thyme'"]
# ["'full of thyme'"]
# ["'a thyme shoot or plant', 'examples': []}, {'gloss': 'an gaunt person (especially a young woman)', 'examples': []}, {'gloss': 'a vexatious person'"]
# ["'obsolete diminutive form surviving in (toponymy) Is-Sgħajtar, meadowland on the south-east of Mosta beyond Imlit; also name of another area in Malta in the neighbourhood of It-Torri tal-Marfa known as the Mosta Palace'"]
# ["'containing thyme', 'examples': []}, {'gloss': 'tasting of thyme'"]
# ["'inquisitive person', 'examples': []}, {'gloss': 'sb. who pries'"]
# ["'prying', 'examples': []}, {'gloss': 'gossipy'"]
# ["'gossiper'"]
# ["'tending to gossip'"]
# ["'chain'"]
# ['"small kingdom (the diminutive form of \'saltna\')"']
# ["'related to kingdoms'"]
# ['"a young king (the diminutive form of \'sultan\')"']
# ["'pertaining to the king', 'examples': []}, {'gloss': 'royal'"]
# ["'a sultana (type of raisin)'"]
# ["'soup bowl'"]
# ["'secure', 'examples': []}, {'gloss': 'safe'"]
# ['"Name of a children\'s game"']
# ["'safeguard'"]
# ["'to safeguard'"]
# ["'permit', 'examples': []}, {'gloss': 'safe-conduct pass'"]
# ["'circuit breaker'"]
# ["'salvation'"]
# ['\'salvage\', \'examples\': [{\'example\': "Infatti t- taħriġ kien jikkonsisti f\' salvataġġ ta\' persuna mill- baħar bl- użu ta\' ħelikopter .", \'type\': \'full\'}]}, {\'gloss\': \'rescue\'']
# ['\'salvation\', \'examples\': [{\'example\': "Wara li rebħu inaspettatament tlieta mill- erbgħa li kien għad baqa\' , l- iskwadra affrontaw fl- aħħar ġurnata lil Bolton Wanderers , fejn kienu jafu li rebħa u riżultat favorevoli fil- partita bejn Everton u Sheffield Wednesday li kienu wkoll qedgħin fiż- żona ta\' relegazzjoni , kien iffiser salvezza .", \'type\': \'full\'}]}, {\'gloss\': \'safety\'']
# ["'Hail Holy Queen (a prayer to Our Lady)'"]
# ["'solvable'"]
# ["'that cannot be solved'"]
# ["'the property of having no solution'"]
# ["'solvent'"]
# ["'insolvent', 'examples': []}, {'gloss': 'having no capital', 'examples': []}, {'gloss': 'bankrupt'"]
# ['\'insolvency\', \'examples\': [{\'example\': "Il- bidliet fil- liġijiet ta\' l- insolvenza fl- Istati Membri u l- iżvilupp tas- suq intern ifissru illi jridu jiġu addattati ċerti disposizzjonijiet ta\' din id- Direttiva .", \'type\': \'full\'}]}, {\'gloss\': \'bankruptcy\'']
# ["'broker', 'examples': []}, {'gloss': 'go-between'"]
# ["'tending to act as a broker'"]
# ['"a small trunk (the diminutive form of \'senduq\')"']
# ['\'A pinnace\', \'examples\': []}, {\'gloss\': "occurs more frequently in the phrase \'qata\' sandar\', (i) ironical for he did not make a good bargain after all, things did not turn out to his advantage as he expected"']
# ["'a small businessman'"]
# ["'chain that forms part of a bridle'"]
# ["'sb. who strings things together'"]
# ["'taking the form of a sequence'"]
# ['\'Hunting-watch\', \'examples\': []}, {\'gloss\': "(botany) \'sapunetta tal-misk\', Musk-ball"']
# ["'soap dish'"]
# ["'soaping', 'examples': []}, {'gloss': 'foaming'"]
# ["'sb. who asks questions'"]
# ["'inquisitive', 'examples': []}, {'gloss': 'overly curious'"]
# ["'tending to form a row'"]
# ['"a short row of people or things (the diminutive form of \'serbut\')"']
# ['"a small cock (the diminutive form of \'serduk\')"']
# ["'an anchor used to moor a ship'"]
# ["'to fine-dra'"]
# ["'guy-rope on a ship'"]
# ['"V-shaped rope tied to the end of the \'lampiera\'"']
# ["'crumbling (used of a stone edifice)'"]
# ['"Falzon explains \'a deluder with fair words or promises\'. A procrastinator. A darner"']
# ["'sb. who talks a lot'"]
# ["'a small grasshopper'"]
# ["'sb. who chatters', 'examples': []}, {'gloss': 'a cricket'"]
# ["'servant', 'examples': [{'example': 'O Mulej , inti bgħatt lis- serv tiegħek fuq din l- art li wettaq il- missjoni li fdajtlu fedelment .', 'type': 'full'}]}, {'gloss': 'serf'"]
# ["'useful', 'examples': []}, {'gloss': 'serviceable'"]
# ["'servile', 'examples': []}, {'gloss': 'obsequious'"]
# ["'in a servile manner', 'examples': []}, {'gloss': 'obsequiously'"]
# ['\'servility\', \'examples\': [{\'example\': "Is- serviliżmu ta\' Malta għall- UE u l- Istati Uniti MINN meta Malta ssieħbet fl- UE u mxejna skont il- politika barranija tal- Unjoni , tlifna l- boxla tal- politika ta\' newtralità skont il- Kostituzzjoni Maltija , u ta\' ħidma attiva għall- paċi .", \'type\': \'full\'}, {\'example\': "Is- serviliżmu ta\' Malta għall- UE u l- Istati Uniti minn meta Malta ssieħbet fl- UE u mxejna skont il- politika barranija tal- Unjoni , tlifna l- boxla tal- politika ta\' newtralità skont il- Kostituzzjoni Maltija , u ta\' ħidma attiva għall- paċi .", \'type\': \'short\'}]}, {\'gloss\': \'obsequiousness\'']
# ["'male nurse'"]
# ["'servitude'"]
# ["'enema'"]
# ['"Occurring in \'servu mutu\', dumbwaiter (a kind of movable table); \'servu di pjazza\', odd man"']
# ["'sb. who embroils others', 'examples': []}, {'gloss': 'sb. who invents stories', 'examples': []}, {'gloss': 'baggy pantaloons'"]
# ["'sb. who eats very little'"]
# ["'sb. who tends to touch things with their fingers'"]
# ["'sth. of no importance'"]
# ["'hollow'"]
# ["'sth. that ticks'"]
# ["'tending to tick'"]
# ["'Name of a game for money (the players throw a large coin at a heap of smaller coins to overthrow them. The coin is thrown around the heap (għaċ-ċirku) or flat (għaċ-ċatt) against it either with full force or slowly)'"]
# ["'tending to tick or beat', 'examples': []}, {'gloss': 'a chatterbox'"]
# ["'sb. who stammers'"]
# ["'tending to stammer'"]
# ['"small drum (the diminutive form of \'tanbur\')"']
# ["'tambourine'"]
# ['\'a sail cupboard on a ship\', \'examples\': []}, {\'gloss\': "a small deck on a traditional Maltese or Gozitan boat (known as the \'dgħajsa\' or \'luzzu\')"']
# ["'bonito (a type of fish)'"]
# ["'tending to drum', 'examples': []}, {'gloss': 'producing drumming sounds'"]
# ["'sb. who softens cushions etc. by beating them'"]
# ["'havin a softening effect'"]
# ["'a piece of frayed thread'"]
# ["'tending to blink'"]
# ["'castanet'"]
# ["'to cause dropsy'"]
# ["'to be infected with dropsy'"]
# ["'infection with dropsy'"]
# ["'dropsy'"]
# ["'to return'"]
# ["'lathe'"]
# ["'sb. who works a lathe', 'examples': []}, {'gloss': 'a turner'"]
# ["'turning on a lathe'"]
# ["'fare for a return ticket'"]
# ['\'film used in cameras\', \'examples\': [{\'example\': "Żied jgħid li maż- żmien , minflok it- tertuqa , fis- sala tal- Oratorju ġiet introdotta s- sistema tal- projectors , li b\' kollox inbidlu tliet darbiet . ", \'type\': \'full\'}]}, {\'gloss\': \'tortoiseshell used in combs etc.\'']
# ["'causing uneasiness or worry'"]
# ["'speaking in a rapid and confused manner'"]
# ["'Little stint (Calidris minuta)'"]
# ["'said of sb. who speaks rapidly and confusedly'"]
# ["'tending to hiss (as of sth. being fried)'"]
# ["'Traditional Maltese recipe for a caper sauce to accompany fish'"]
# ["'development'"]
# ["'invincible'"]
# ["'winnings'"]
# ["'triumph', 'examples': []}, {'gloss': 'victory'"]
# ["'blowing hard (used of the wind)', 'examples': []}, {'gloss': 'howling', 'examples': []}, {'gloss': 'hurling violently'"]
# ['\'vibration\', \'examples\': [{\'example\': "U huwa u jdawwarha fuq il- fus ta\' sebgħu l- werrej qagħad jimmaġinaha għaddejja tvenvin ġo l- arja bir- riħ isaffar ġo toqbitha .", \'type\': \'full\'}, {\'example\': "U huwa u jdawwarha fuq il- fus ta\' sebgħu l- werrej qagħad jimmaġinaha għaddejja tvenvin ġol- arja bir- riħ isaffar ġo toqbitha .", \'type\': \'short\'}]}, {\'gloss\': \'thowing with great force\', \'examples\': []}, {\'gloss\': \'howling (of the wind)\'']
# ["'variable', 'examples': []}, {'gloss': 'changeable'"]
# ["'invariable'"]
# ["'variability'"]
# ["'Invariability'"]
# ["'a variant of sth.', 'examples': [{'example': 'Bħala varjant mill- istejjer u l- ħrejjef , il- kbar kienu xi drabi joqogħdu jħabblulna rasna bil- ħaġa moħġaġa .', 'type': 'full'}]}, {'gloss': 'different version of sth.'"]
# ["'varying', 'examples': []}, {'gloss': 'changing'"]
# ["'sb. who howls in pain'"]
# ["'tending to howl'"]
# ["'sb. who talks a lot', 'examples': []}, {'gloss': 'a bird that caws or yacks'"]
# ["'talkative', 'examples': []}, {'gloss': 'tending to caw or yack (like a crow, rook, etc)'"]
# ["'sth. that produces a whirring or humming sound'"]
# ["'whirring', 'examples': [{'example': '44 swied ta’ qalb , imma malli mbagħad nidħlu fl- uffiċċju ta’ missieri u nxomm ir- riħa tal- karti u nisma’ t- twerdin tal- fannijiet u t- tektik tat- tajprajters kont inħossni dħalt fid- dinja tiegħi .', 'type': 'full'}, {'example': 'Imma malli mbagħad nidħlu fl- uffiċċju ta’ missieri u nxomm ir- riħa tal- karti u nisma’ t- twerdin tal- fannijiet u t- tektik tat- tajprajters kont inħossni dħalt fid- dinja tiegħi .', 'type': 'short'}]}, {'gloss': 'humming', 'examples': []}, {'gloss': 'babbling of voices'"]
# ["'tending to whir or hum'"]
# ['"small cockroach (the diminutive form of \'wirdiena\')"']
# ["'sb. who scares', 'examples': []}, {'gloss': 'sb. who terrorises'"]
# ["'horrific', 'examples': []}, {'gloss': 'frightening'"]
# ["'tending to scream', 'examples': []}, {'gloss': 'having a high-pitched voice'"]
# ['"a small cricket (the diminutive form of \'werżieq\')"']
# ["'sb. who whispers', 'examples': []}, {'gloss': 'sb. who spreads rumours'"]
# ["'speaking in a whisper'"]
# ["'male goat', 'examples': []}, {'gloss': 'an uncouth individual'"]
# ["'honking of car horns', 'examples': []}, {'gloss': 'bleating of goats', 'examples': []}, {'gloss': 'idle chit-chat'"]
# ["'a bigot', 'examples': []}, {'gloss': 'a hypocrite'"]
# ["'hypocritical', 'examples': []}, {'gloss': 'bigoted', 'examples': []}, {'gloss': 'tending to indulge in malicious gossip'"]
# ["'sb. who braids or intertwines'"]
# ["'intertwining', 'examples': []}, {'gloss': 'braided'"]
# ["'tending to cause drowsiness', 'examples': []}, {'gloss': 'soporific'"]
# ["'poppy'"]
# ["'demonology', 'examples': []}, {'gloss': 'study of the history and mythology of the devil'"]
# ['"a small devil (the diminutive form of \'xitan\')"']
# ["'sb. who depreciates or displays contempt for sth.'"]
# ["'contemptuous'"]
# ['"An undefined part of the human body (\'nħossni xbajt sa xmnieqi\', I am fed up to the back teeth)"']
# ['\'broadcaster\', \'examples\': [{\'example\': "Tul il- karriera tiegħu bħala xandar professjonali u amministratur fil- midja , kien minn ta\' quddiem fit- trawwim ta\' kuxjenza nazzjonali fil- wirt ta’ pajjiżna u fl- esekuzjoni ta\' xogħlijiet letterarji u drammatiċi bl- ilsien Malti fuq il- mezzi tax- xandir .", \'type\': \'full\'}]}, {\'gloss\': \'broadcasting company\'']
# ["'having the job of broadcasting', 'examples': []}, {'gloss': 'tending to divulge private information'"]
# ["'unsteady (due to drunkenness etc)'"]
# ["'sb. who tilts from side to side'"]
# ["'tending to swing', 'examples': []}, {'gloss': 'tending to stagger'"]
# ["'disgust'"]
# ["'tending to take root', 'examples': []}, {'gloss': 'tending to produce fruit in bunches'"]
# ["'tending to occur in bunches', 'examples': []}, {'gloss': 'tending to take root'"]
# ['"a small bunch or root (the diminutive form of \'xenxul\')"']
# ["'a bunch of grapes which has just begun to form', 'examples': []}, {'gloss': 'a bunch'"]
# ["'sb. who likes to dunk'"]
# ["'having the habit of dunking'"]
# ["'slope', 'examples': []}, {'gloss': 'one side of a place (e.g. a village or town)'"]
# ["'sb. who tends to topple things over'"]
# ["'tending to topple things over', 'examples': []}, {'gloss': 'having a penchant for sth.', 'examples': []}, {'gloss': 'holding a preference for a particular view'"]
# ['"Occurring in the phrase \'ħamiem xaqliban/ħamiem tax-xaqliban\', tumbler (king of pigeon)"']
# ["'sb. wearing stained clothes'"]
# ["'spattered with blood'"]
# ["'sb. who tends to have bloodstains on their clothes (typically a butcher or slaughterer)', 'examples': []}, {'gloss': 'sb. who is bad at dissecting'"]
# ["'wearing blood-stained clothes'"]
# ["'sb. who throws violently'"]
# ["'having the capacity to throw forcefully'"]
# ["'a gossip-monger'"]
# ["'tending to gossip'"]
# ["'jutting out (used of stone blocks)'"]
# ["'the sound made by certain birds (especially finches and robins)'"]
# ["'sb. who clashes cymbals'"]
# ["'producing a clashing sound'"]
# ["'starling'"]
# ["'sb. who scorns'"]
# ["'exhibiting scorn or contempt'"]
# ["'producing an oozing noise'"]
# ["'papyrus plant'"]
# ["'field pea'"]
# ["'sth. that causes swelling', 'examples': []}, {'gloss': 'sb. who tends to flatter'"]
# ["'tending to swell'"]
# ["'sb. who wiggles'"]
# ["'wiggling', 'examples': []}, {'gloss': 'wriggling'"]
# ["'A game in which children try to get a button out of a circle made by a whip-toy'"]
# ["'sb. who plays an instrument incompetently'"]
# ["'tending to thrum'"]
# ["'to frolic', 'examples': []}, {'gloss': 'to romp', 'examples': []}, {'gloss': 'to exhibit idle behaviour'"]
# ["'to waste time idling about', 'examples': []}, {'gloss': 'to have no purpose in life'"]
# ["'having the colour of saffron', 'examples': []}, {'gloss': 'yellow'"]
# ["'downy', 'examples': []}, {'gloss': 'covered with soft hair'"]
# ["'sb. who tends to be rude'"]
# ["'rude', 'examples': []}, {'gloss': 'irascible'"]
# ["'a bolt of thunder'"]
# ["'a traditional musical instrument'"]
# ["'an alcoholic drink made from anise (cf. sambuca)'"]
# ["'a mixed drink that includes anise spirit (i.e. żambur)'"]
# ["'sb. who drinks a lot', 'examples': []}, {'gloss': 'a lush'"]
# ['"a small broom basket (the diminutive form of \'żenbil\')"']
# ["'oblong', 'examples': []}, {'gloss': 'of an elongated shape'"]
# ["'sb. who rocks a child in a cradle'"]
# ["'having a rocking motion'"]
# ["'One who wears a dress, shoes, etc. for the first time'"]
# ["'buzzing', 'examples': []}, {'gloss': 'tending to wear new clothes very often'"]
# ['"a small shoe (the diminutive form of \'żarbuna\')"']
# ['"small pair of shoes (the diminutive form of \'żarbun\')"']
# ["'small shoot of a plant, such as a vine'"]
# ["'sb. who dismantles'"]
# ["'removal of objects', 'examples': []}, {'gloss': 'dismantling', 'examples': []}, {'gloss': 'unharnessing'"]
# ['"Name of a children\'s game"']
# ["'sth. that enables things to slide down'"]
# ["'slippery', 'examples': []}, {'gloss': 'causing sliding'"]
# ["'causing sliding', 'examples': []}, {'gloss': 'having a downward incline'"]
# ["'sth. that buzzes or rattles', 'examples': []}, {'gloss': 'sb. who plays the trumpet aloudly', 'examples': []}, {'gloss': 'sb. whose voice is high-pitched'"]
# ["'tending to twang'"]
# ["'cricket', 'examples': []}, {'gloss': 'grasshopper'"]
# ["'causing squeaking or creaking'"]
# ["'tending to creak'"]
# ["'swarming'"]
# ["'colloquial term for marijuana'"]
# ['\'writing\', \'examples\': [{\'example\': "Din is- sena se jkun hemm programmi ta’ kitba għall- familja minbarra diversi tnedijiet ta’ kotba u intervisti ta\' kittieba u nies oħra involuti fid- dinja tal- ktieb .", \'type\': \'full\'}]}, {\'gloss\': \'the act of writing\', \'examples\': []}, {\'gloss\': \'written text\', \'examples\': [{\'example\': \'Kull karta kienet miksija b’ kitba rqiqa sabiħa , isem wara isem , wieħed wara l- ieħor .\', \'type\': \'full\'}]}, {\'gloss\': \'creative writing (prose, poetry etc)\'']
# ['\'caterpillar\', \'examples\': [{\'example\': "Huwa x- xagħat li jfaqqas mill- bajd li jagħmel l- aktar ħsara lill- palma hekk kif dan jibda jħaffer \'il ġewwa fiz- zokk tal- palma .", \'type\': \'full\'}, {\'example\': "Ix- xagħat li jfaqqas mill- bajd jagħmel l- aktar ħsara lill- palma hekk kif dan jibda jħaffer \'il ġewwa fiz- zokk tal- palma .", \'type\': \'short\'}]}, {\'gloss\': \'eruca\'']

# %%
df_lexemes
# Out:
#                             _id     lemma  \
# 0      5200a366e36f237975000783    badbad
# 1      5200a366e36f237975000784   tbadbad
# 2      5200a366e36f237975000785   bagħbas
# 3      5200a366e36f237975000786  tbagħbas
# 4      5200a366e36f237975000787   bagħtar
# ...                         ...       ...
# 16833  569002ffdff0600b5ab1434e  mgħarwel
# 16837  56966190189d1d6376783b94    ħaxixa
# 16846  569794e16e68020d08030c4d     kitba
# 16982  5714de59418362c403b9c3ff    xagħat
# 18950  5c584ad8bd4e49047363e116    tidris
#
#                                       root                        sources  \
# 0                  {'radicals': 'b-d-b-d'}  ['Spagnol2011', 'Falzon2013']
# 1                  {'radicals': 'b-d-b-d'}                ['Spagnol2011']
# 2                 {'radicals': 'b-għ-b-s'}  ['Spagnol2011', 'Falzon2013']
# 3                 {'radicals': 'b-għ-b-s'}                ['Spagnol2011']
# 4                 {'radicals': 'b-għ-t-r'}                ['Spagnol2011']
# ...                                    ...                            ...
# 16833             {'radicals': 'għ-r-w-l'}     ['UserFeedback', 'DM2015']
# 16837                {'radicals': 'ħ-x-x'}                     ['DM2015']
# 16846                {'radicals': 'k-t-b'}                     ['DM2015']
# 16982               {'radicals': 'x-għ-t'}                     ['DM2015']
# 18950  {'radicals': 'd-r-s', 'variant': 1}                     ['DM2015']
#
#       phonetic   pos                                            glosses  \
# 0       bɐdbɐt  VERB  ['to fornicate', 'examples': []}, {'gloss': 't...
# 1      dbɐdbɐt  VERB        ['to act in a rough or anti-social manner']
# 2       bɐːbɐs  VERB  ['to touch', 'examples': []}, {'gloss': 'to fo...
# 3      dbɐːbɐs  VERB  ['to be damaged as a result of handling', 'exa...
# 4       bɐːtɐr  VERB                            ['to wade through mud']
# ...        ...   ...                                                ...
# 16833  mɐːrwɛl   ADJ                                       ['swarming']
# 16837   hɐʃɪʃɐ  NOUN                  ['colloquial term for marijuana']
# 16846    kɪdbɐ  NOUN  ['writing', 'examples': [{'example': "Din is- ...
# 16982     ʃɐːt  NOUN  ['caterpillar', 'examples': [{'example': "Huwa...
# 18950   tɪdrɪs  NOUN  [<re.Match object; span=(0, 46), match="'gloss...
#
#                                                 examples
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 16833                                               None
# 16837  Fetaħ il- kexxun tal- komodina , fejn snin ilu...
# 16846                                               None
# 16982                                               None
# 18950                                                 []
#
# [10340 rows x 8 columns]

# %%
df_lexemes
# Out:
#                             _id     lemma  \
# 0      5200a366e36f237975000783    badbad
# 1      5200a366e36f237975000784   tbadbad
# 2      5200a366e36f237975000785   bagħbas
# 3      5200a366e36f237975000786  tbagħbas
# 4      5200a366e36f237975000787   bagħtar
# ...                         ...       ...
# 16833  569002ffdff0600b5ab1434e  mgħarwel
# 16837  56966190189d1d6376783b94    ħaxixa
# 16846  569794e16e68020d08030c4d     kitba
# 16982  5714de59418362c403b9c3ff    xagħat
# 18950  5c584ad8bd4e49047363e116    tidris
#
#                                       root                        sources  \
# 0                  {'radicals': 'b-d-b-d'}  ['Spagnol2011', 'Falzon2013']
# 1                  {'radicals': 'b-d-b-d'}                ['Spagnol2011']
# 2                 {'radicals': 'b-għ-b-s'}  ['Spagnol2011', 'Falzon2013']
# 3                 {'radicals': 'b-għ-b-s'}                ['Spagnol2011']
# 4                 {'radicals': 'b-għ-t-r'}                ['Spagnol2011']
# ...                                    ...                            ...
# 16833             {'radicals': 'għ-r-w-l'}     ['UserFeedback', 'DM2015']
# 16837                {'radicals': 'ħ-x-x'}                     ['DM2015']
# 16846                {'radicals': 'k-t-b'}                     ['DM2015']
# 16982               {'radicals': 'x-għ-t'}                     ['DM2015']
# 18950  {'radicals': 'd-r-s', 'variant': 1}                     ['DM2015']
#
#       phonetic   pos                                            glosses
# 0       bɐdbɐt  VERB                        to fornicate,to cough a lot
# 1      dbɐdbɐt  VERB            to act in a rough or anti-social manner
# 2       bɐːbɐs  VERB                                 to touch,to fondle
# 3      dbɐːbɐs  VERB  to be damaged as a result of handling,to be me...
# 4       bɐːtɐr  VERB                                to wade through mud
# ...        ...   ...                                                ...
# 16833  mɐːrwɛl   ADJ                                           swarming
# 16837   hɐʃɪʃɐ  NOUN                      colloquial term for marijuana
# 16846    kɪdbɐ  NOUN  writing,the act of writing,written text,creati...
# 16982     ʃɐːt  NOUN  caterpillar, "Ix- xagħat li jfaqqas mill- bajd...
# 18950   tɪdrɪs  NOUN                irritation or excessive sensitivity
#
# [10340 rows x 7 columns]

# %% [markdown]
# ### Parsing roots

# %%
regex = re.compile('[a-zġħċż][a-zġħċż]?-[a-zġħċż][a-zġħċż]?-[a-zġħċż][a-zġħċż]?-?[a-zġħċż]?[a-zġħċż]?',)

regex.findall('b-d-b-t')[0]
df_lexemes['root'] = df_lexemes['root'].apply(lambda s: ''.join(regex.findall(s)))
df_lexemes
# Out:
#                             _id     lemma      root  \
# 0      5200a366e36f237975000783    badbad   b-d-b-d
# 1      5200a366e36f237975000784   tbadbad   b-d-b-d
# 2      5200a366e36f237975000785   bagħbas  b-għ-b-s
# 3      5200a366e36f237975000786  tbagħbas  b-għ-b-s
# 4      5200a366e36f237975000787   bagħtar  b-għ-t-r
# ...                         ...       ...       ...
# 16833  569002ffdff0600b5ab1434e  mgħarwel  għ-r-w-l
# 16837  56966190189d1d6376783b94    ħaxixa     ħ-x-x
# 16846  569794e16e68020d08030c4d     kitba     k-t-b
# 16982  5714de59418362c403b9c3ff    xagħat    x-għ-t
# 18950  5c584ad8bd4e49047363e116    tidris     d-r-s
#
#                              sources phonetic   pos  \
# 0      ['Spagnol2011', 'Falzon2013']   bɐdbɐt  VERB
# 1                    ['Spagnol2011']  dbɐdbɐt  VERB
# 2      ['Spagnol2011', 'Falzon2013']   bɐːbɐs  VERB
# 3                    ['Spagnol2011']  dbɐːbɐs  VERB
# 4                    ['Spagnol2011']   bɐːtɐr  VERB
# ...                              ...      ...   ...
# 16833     ['UserFeedback', 'DM2015']  mɐːrwɛl   ADJ
# 16837                     ['DM2015']   hɐʃɪʃɐ  NOUN
# 16846                     ['DM2015']    kɪdbɐ  NOUN
# 16982                     ['DM2015']     ʃɐːt  NOUN
# 18950                     ['DM2015']   tɪdrɪs  NOUN
#
#                                                  glosses
# 0                            to fornicate,to cough a lot
# 1                to act in a rough or anti-social manner
# 2                                     to touch,to fondle
# 3      to be damaged as a result of handling,to be me...
# 4                                    to wade through mud
# ...                                                  ...
# 16833                                           swarming
# 16837                      colloquial term for marijuana
# 16846  writing,the act of writing,written text,creati...
# 16982  caterpillar, "Ix- xagħat li jfaqqas mill- bajd...
# 18950                irritation or excessive sensitivity
#
# [10340 rows x 7 columns]

# %% [markdown]
# ### Replacing abbreviations

# %%
df_lexemes[df_lexemes['glosses'].str.contains('sth.')]
# Out:
#                             _id     lemma      root          sources  \
# 42     5200a366e36f2379750007ae   bergħen  b-r-għ-n  ['Spagnol2011']
# 58     5200a366e36f2379750007be    bexlek   b-x-l-k  ['Spagnol2011']
# 61     5200a366e36f2379750007c2    bażwar   b-ż-w-r  ['Spagnol2011']
# 66     5200a366e36f2379750007c7   tbeżbeż   b-ż-b-ż  ['Spagnol2011']
# 76     5200a366e36f2379750007d1    ċeflaq   ċ-f-l-q  ['Spagnol2011']
# ...                         ...       ...       ...              ...
# 16755  56802c9b5afadbfd19202677   xemnieq   x-m-n-q       ['DM2015']
# 16772  568034c35afadbfd19202722  xaqliebi   x-q-l-b       ['DM2015']
# 16792  568047995afadbfd192027fc   żembieħ   ż-m-b-ħ       ['DM2015']
# 16822  568075035afadbfd19204436   żerżieq   ż-r-ż-q       ['DM2015']
# 16825  5680775b5afadbfd19204453    żarżar   ż-r-ż-r       ['DM2015']
#
#        phonetic   pos                                            glosses
# 42       bɛrɛːn  VERB                to mull sth. over,to make sb. angry
# 58       bɛʃlɛk  VERB                     to occupy one's mind with sth.
# 61       bɐzwɐr  VERB  to exhaust sb.,to perform a task clumsily,to c...
# 66      dbɛzbɛs  VERB  to be reprimanded,to be castigated,to experien...
# 76       ʧɛflɐʔ  VERB                                      to shift sth.
# ...         ...   ...                                                ...
# 16755   ʃɛmnɪːʔ  NOUN  sb. who depreciates or displays contempt for sth.
# 16772  ʃɐʔlɪːbɪ   ADJ  tending to topple things over,having a penchan...
# 16792   zɛmbɪːh  NOUN  sth. that causes swelling,sb. who tends to fla...
# 16822   zɛrzɪːʔ  NOUN             sth. that enables things to slide down
# 16825    zɐrzɐr  NOUN  sth. that buzzes or rattles,sb. who plays the ...
#
# [543 rows x 7 columns]

# %%
df_lexemes['glosses'] = df_lexemes['glosses'].apply(lambda s: s.replace('sb.','somebody')
                                                    .replace('sth.','something')
                                                    .replace('sb','somebody')
                                                    .replace('sth','something'))

df_lexemes[df_lexemes['glosses'].str.contains('somebody')]
# Out:
#                             _id     lemma      root  \
# 6      5200a366e36f237975000789    bahrad   b-h-r-d
# 21     5200a366e36f237975000799    bambal   b-m-b-l
# 30     5200a366e36f2379750007a2    baqbaq   b-q-b-q
# 42     5200a366e36f2379750007ae   bergħen  b-r-għ-n
# 59     5200a366e36f2379750007bf    bixkel   b-x-k-l
# ...                         ...       ...       ...
# 16803  5680665b5afadbfd19203a67   żekżiek   ż-k-ż-k
# 16809  568068e65afadbfd19204392   żambari   ż-m-b-r
# 16812  56806ba15afadbfd192043b2   żengiel   ż-n-g-l
# 16819  568072005afadbfd19204406  żarmatur   ż-r-m-j
# 16825  5680775b5afadbfd19204453    żarżar   ż-r-ż-r
#
#                              sources  phonetic   pos  \
# 6                    ['Spagnol2011']    bɐːrɐt  VERB
# 21                   ['Spagnol2011']    bɐmbɐl  VERB
# 30                   ['Spagnol2011']    bɐʔbɐʔ  VERB
# 42                   ['Spagnol2011']    bɛrɛːn  VERB
# 59     ['Spagnol2011', 'Falzon2013']    bɪʃkɛl  VERB
# ...                              ...       ...   ...
# 16803                     ['DM2015']   zɛgzɪːk  NOUN
# 16809                     ['DM2015']   zɐmbɐrɪ   ADJ
# 16812                     ['DM2015']   zɛngɪːl  NOUN
# 16819                     ['DM2015']  zɐrmɐtʊr  NOUN
# 16825                     ['DM2015']    zɐrzɐr  NOUN
#
#                                                  glosses
# 6      to make somebody indulge in enjoyment or frivo...
# 21        to hit somebody repeatedly,to punish,to pummel
# 30     to bubble,to gurgle,to boil,to get somebody wo...
# 42         to mull something over,to make somebody angry
# 59     to entwine,to make wicker,to involve somebody ...
# ...                                                  ...
# 16803                      somebody who tends to be rude
# 16809                   somebody who drinks a lot,a lush
# 16812             somebody who rocks a child in a cradle
# 16819                            somebody who dismantles
# 16825  something that buzzes or rattles,somebody who ...
#
# [1004 rows x 7 columns]

# %%
df_lexemes = df_lexemes.reset_index(drop=True)
df_lexemes.to_csv(final_lexemes_path, index=False)
